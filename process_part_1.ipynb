# %% [markdown]
# # UPLOAD FILES FOR "raw", "ibv", "ues" and later "kit"

# %% [markdown]
# # TDL: upload all those files and change a row it "kit" csv
# manually do exceptions for "with"

# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame
#from numpy import sLength

#df, ibv
raw = pd.read_csv('ttdptest3.csv', encoding = "ISO-8859-1")
ibv = pd.read_csv('ibv.csv', encoding = "ISO-8859-1")
ues = pd.read_csv('ues.csv', encoding = "ISO-8859-1")
#print(df.columns)
#print(ibv.columns)

# %%
raw
# Out:
#                   ItemNr        EAN_No  tariff_number  \
# 0     ADV.01.129.75000/B  4.052572e+12     42021910.0
# 1     ADV.01.129.75000/S  4.052572e+12     42021910.0
# 2     ADV.01.622.75001/B  4.052572e+12     42021910.0
# 3     ADV.01.622.75001/S  4.052572e+12     42021910.0
# 4       ADV.01.622.76000  4.052572e+12     87141090.0
# ...                  ...           ...            ...
# 3799   WER.POS.013.10000  4.052572e+12     63079098.0
# 3800   WER.POS.019.10001  4.052572e+12     63079098.0
# 3801   WER.POS.021.10000  4.052572e+12     63079098.0
# 3802      WFF.00.138.100  4.052572e+12     87141090.0
# 3803  WZX.00.014.10001/S  4.052572e+12     87141090.0
#
#                          name1_GER  \
# 0             Adventure-Set Gepäck
# 1             Adventure-Set Gepäck
# 2             Adventure-Set Gepäck
# 3             Adventure-Set Gepäck
# 4             Adventure-Set Schutz
# ...                            ...
# 3799           Bowflag Legend Gear
# ...

# %%
ibv
# Out:
#       internal_id            type           feed_name  \
# 0            5509  Inventory Item      CPA.00.424.113
# 1            5465  Inventory Item  CPA.00.424.12400.B
# 2           75776  Inventory Item      CPA.00.424.114
# 3            6150  Inventory Item      CPA.00.424.115
# 4            4943  Inventory Item      CPA.00.424.112
# ...           ...             ...                 ...
# 7262         9787  Inventory Item            EC.09351
# 7263        69273  Inventory Item      TRE.00.475.101
# 7264         4747  Inventory Item  BCK.TRE.00.037.100
# 7265         7284  Inventory Item  GTH.08.428.100.TWT
# 7266        20838  Inventory Item      TRT.00.475.225
#
#                                             description  \
# 0                  "SW-MOTECH 1"" ball for camera mount
# 1                  "SW-MOTECH 1"" ball for GoPro camera
# 2                     "SW-MOTECH 1"" ball for GPS mount
# 3             "SW-MOTECH 1"" ball for M10 mirror thread
# ...

# %%
ues
# Out:
#                   ItemNr                    In NS?  \
# 0     ADV.01.129.75000/B                     * KIT
# 1     ADV.01.129.75000/S                     * KIT
# 2     ADV.01.622.75001/B                     * KIT
# 3     ADV.01.622.75001/S                     * KIT
# 4       ADV.01.622.76000                     * KIT
# ...                  ...                       ...
# 1244       VPS-007-01-BK        * Barkbusters BB01
# 1245       VPS-007-01-GR  *ignore "AU" barkbusters
# 1246       VPS-007-01-OR        * Barkbusters BB01
# 1247       VPS-007-01-PK        * Barkbusters BB01
# 1248       VPS-007-01-WH  *ignore "AU" barkbusters
#
#                                                 TT Name
# 0     SW-MOTECH Adventure-Set Luggage Black. Honda N...
# 1     SW-MOTECH Adventure set Luggage Silver. Honda ...
# 2     SW-MOTECH Adventure set luggage Black. Honda C...
# 3     SW-MOTECH Adventure set luggage Silver. Honda ...
# 4     SW-MOTECH Adventure set Protection Honda CRF10...
# ...

# %%
#if internal id in both already uploaded

# %%
val = ibv['vendor_code'].unique()
val1 = ues['ItemNr'].unique()

firstquery = raw.query("ItemNr not in @val1 and ItemNr not in @val")

# %%
firstquery
# Out:
#                      ItemNr        EAN_No  tariff_number  \
# 100        ALK.00.165.16303  4.052572e+12     83014090.0
# 101        ALK.00.165.16503  4.052572e+12     83014090.0
# 256   BC.HTA.04.740.10500/B  4.052572e+12            NaN
# 259   BC.HTA.04.915.30000/B  4.052572e+12            NaN
# 260   BC.HTA.04.958.30000/B  4.052572e+12     42021250.0
# ...                     ...           ...            ...
# 3583           TORSTEN.TEST  4.052572e+12     27101225.0
# 3584      TORSTEN.TEST_NILS  4.052572e+12     27101225.0
# 3600     TRT.00.475.14000/B  4.052572e+12     87141090.0
# 3781      WER.GIV.017.10001  4.052572e+12     49119900.0
# 3785      WER.GIV.023.10002  4.052572e+12            NaN
#
#                           name1_GER  \
# 100               TRAX Schloss-Satz
# 101               TRAX Schloss-Satz
# 256       BLAZE H Satteltaschen-Set
# 259   URBAN ABS Seitenkoffer-System
# 260   URBAN ABS Seitenkoffer-System
# ...                             ...
# ...

# %% [markdown]
# filtered out 131 (43 need to be left)

# %%
fq2 = firstquery[firstquery['ItemGroup'] != 'BB001']

# %%
fq2
# Out:
#                      ItemNr        EAN_No  tariff_number  \
# 100        ALK.00.165.16303  4.052572e+12     83014090.0
# 101        ALK.00.165.16503  4.052572e+12     83014090.0
# 256   BC.HTA.04.740.10500/B  4.052572e+12            NaN
# 259   BC.HTA.04.915.30000/B  4.052572e+12            NaN
# 260   BC.HTA.04.958.30000/B  4.052572e+12     42021250.0
# ...                     ...           ...            ...
# 3583           TORSTEN.TEST  4.052572e+12     27101225.0
# 3584      TORSTEN.TEST_NILS  4.052572e+12     27101225.0
# 3600     TRT.00.475.14000/B  4.052572e+12     87141090.0
# 3781      WER.GIV.017.10001  4.052572e+12     49119900.0
# 3785      WER.GIV.023.10002  4.052572e+12            NaN
#
#                           name1_GER  \
# 100               TRAX Schloss-Satz
# 101               TRAX Schloss-Satz
# 256       BLAZE H Satteltaschen-Set
# 259   URBAN ABS Seitenkoffer-System
# 260   URBAN ABS Seitenkoffer-System
# ...                             ...
# ...

# %% [markdown]
# new_path = r"C:\Users\Colleen\Documents\\"
# writer = pd.ExcelWriter(new_path, engine='xlsxwriter')
# df.to_excel(writer)

# %% [markdown]
# fq2.to_csv('fq2test.csv')

# %%
fq2 = firstquery[firstquery['ItemGroup'] != 'BB001']

# %% [markdown]
# # also u gotta do the made in AU/NOT CE

# %% [markdown]
# ItemNr
#
# B-
# BB
# BHG
# BLG
# BSC
# BSS
# BTC
# EGO
# JET
# STM
# TCM
# VPS
#
# SET

# %%
fq2_test = firstquery[~firstquery['ItemNr'].astype(str).str.startswith('B-','BB')]
fq2_test
# Out:
#                      ItemNr        EAN_No  tariff_number  \
# 100        ALK.00.165.16303  4.052572e+12     83014090.0
# 101        ALK.00.165.16503  4.052572e+12     83014090.0
# 256   BC.HTA.04.740.10500/B  4.052572e+12            NaN
# 259   BC.HTA.04.915.30000/B  4.052572e+12            NaN
# 260   BC.HTA.04.958.30000/B  4.052572e+12     42021250.0
# ...                     ...           ...            ...
# 3583           TORSTEN.TEST  4.052572e+12     27101225.0
# 3584      TORSTEN.TEST_NILS  4.052572e+12     27101225.0
# 3600     TRT.00.475.14000/B  4.052572e+12     87141090.0
# 3781      WER.GIV.017.10001  4.052572e+12     49119900.0
# 3785      WER.GIV.023.10002  4.052572e+12            NaN
#
#                           name1_GER  \
# 100               TRAX Schloss-Satz
# 101               TRAX Schloss-Satz
# 256       BLAZE H Satteltaschen-Set
# 259   URBAN ABS Seitenkoffer-System
# 260   URBAN ABS Seitenkoffer-System
# ...                             ...
# ...

# %%
fq3_test = fq2_test[~fq2_test['ItemNr'].astype(str).str.startswith('BHG','BLG')]
fq3_test
# Out:
#                      ItemNr        EAN_No  tariff_number  \
# 100        ALK.00.165.16303  4.052572e+12     83014090.0
# 101        ALK.00.165.16503  4.052572e+12     83014090.0
# 256   BC.HTA.04.740.10500/B  4.052572e+12            NaN
# 259   BC.HTA.04.915.30000/B  4.052572e+12            NaN
# 260   BC.HTA.04.958.30000/B  4.052572e+12     42021250.0
# ...                     ...           ...            ...
# 3583           TORSTEN.TEST  4.052572e+12     27101225.0
# 3584      TORSTEN.TEST_NILS  4.052572e+12     27101225.0
# 3600     TRT.00.475.14000/B  4.052572e+12     87141090.0
# 3781      WER.GIV.017.10001  4.052572e+12     49119900.0
# 3785      WER.GIV.023.10002  4.052572e+12            NaN
#
#                           name1_GER  \
# 100               TRAX Schloss-Satz
# 101               TRAX Schloss-Satz
# 256       BLAZE H Satteltaschen-Set
# 259   URBAN ABS Seitenkoffer-System
# 260   URBAN ABS Seitenkoffer-System
# ...                             ...
# ...

# %%
fq4_test = fq3_test[~fq3_test['ItemNr'].astype(str).str.startswith('BSC','BSS')]
fq4_test
# Out:
#                      ItemNr        EAN_No  tariff_number  \
# 100        ALK.00.165.16303  4.052572e+12     83014090.0
# 101        ALK.00.165.16503  4.052572e+12     83014090.0
# 256   BC.HTA.04.740.10500/B  4.052572e+12            NaN
# 259   BC.HTA.04.915.30000/B  4.052572e+12            NaN
# 260   BC.HTA.04.958.30000/B  4.052572e+12     42021250.0
# ...                     ...           ...            ...
# 3583           TORSTEN.TEST  4.052572e+12     27101225.0
# 3584      TORSTEN.TEST_NILS  4.052572e+12     27101225.0
# 3600     TRT.00.475.14000/B  4.052572e+12     87141090.0
# 3781      WER.GIV.017.10001  4.052572e+12     49119900.0
# 3785      WER.GIV.023.10002  4.052572e+12            NaN
#
#                           name1_GER  \
# 100               TRAX Schloss-Satz
# 101               TRAX Schloss-Satz
# 256       BLAZE H Satteltaschen-Set
# 259   URBAN ABS Seitenkoffer-System
# 260   URBAN ABS Seitenkoffer-System
# ...                             ...
# ...

# %%
fq5_test = fq4_test[~fq4_test['ItemNr'].astype(str).str.startswith('BTC','EGO')]
fq5_test
# Out:
#                      ItemNr        EAN_No  tariff_number  \
# 100        ALK.00.165.16303  4.052572e+12     83014090.0
# 101        ALK.00.165.16503  4.052572e+12     83014090.0
# 256   BC.HTA.04.740.10500/B  4.052572e+12            NaN
# 259   BC.HTA.04.915.30000/B  4.052572e+12            NaN
# 260   BC.HTA.04.958.30000/B  4.052572e+12     42021250.0
# ...                     ...           ...            ...
# 3583           TORSTEN.TEST  4.052572e+12     27101225.0
# 3584      TORSTEN.TEST_NILS  4.052572e+12     27101225.0
# 3600     TRT.00.475.14000/B  4.052572e+12     87141090.0
# 3781      WER.GIV.017.10001  4.052572e+12     49119900.0
# 3785      WER.GIV.023.10002  4.052572e+12            NaN
#
#                           name1_GER  \
# 100               TRAX Schloss-Satz
# 101               TRAX Schloss-Satz
# 256       BLAZE H Satteltaschen-Set
# 259   URBAN ABS Seitenkoffer-System
# 260   URBAN ABS Seitenkoffer-System
# ...                             ...
# ...

# %%
fq6_test = fq5_test[~fq5_test['ItemNr'].astype(str).str.startswith('JET','STM')]
fq6_test
# Out:
#                      ItemNr        EAN_No  tariff_number  \
# 100        ALK.00.165.16303  4.052572e+12     83014090.0
# 101        ALK.00.165.16503  4.052572e+12     83014090.0
# 256   BC.HTA.04.740.10500/B  4.052572e+12            NaN
# 259   BC.HTA.04.915.30000/B  4.052572e+12            NaN
# 260   BC.HTA.04.958.30000/B  4.052572e+12     42021250.0
# ...                     ...           ...            ...
# 3583           TORSTEN.TEST  4.052572e+12     27101225.0
# 3584      TORSTEN.TEST_NILS  4.052572e+12     27101225.0
# 3600     TRT.00.475.14000/B  4.052572e+12     87141090.0
# 3781      WER.GIV.017.10001  4.052572e+12     49119900.0
# 3785      WER.GIV.023.10002  4.052572e+12            NaN
#
#                           name1_GER  \
# 100               TRAX Schloss-Satz
# 101               TRAX Schloss-Satz
# 256       BLAZE H Satteltaschen-Set
# 259   URBAN ABS Seitenkoffer-System
# 260   URBAN ABS Seitenkoffer-System
# ...                             ...
# ...

# %%
fq7_test = fq6_test[~fq6_test['ItemNr'].astype(str).str.startswith('TCM','VPS')]
fq7_test
# Out:
#                      ItemNr        EAN_No  tariff_number  \
# 100        ALK.00.165.16303  4.052572e+12     83014090.0
# 101        ALK.00.165.16503  4.052572e+12     83014090.0
# 256   BC.HTA.04.740.10500/B  4.052572e+12            NaN
# 259   BC.HTA.04.915.30000/B  4.052572e+12            NaN
# 260   BC.HTA.04.958.30000/B  4.052572e+12     42021250.0
# ...                     ...           ...            ...
# 3583           TORSTEN.TEST  4.052572e+12     27101225.0
# 3584      TORSTEN.TEST_NILS  4.052572e+12     27101225.0
# 3600     TRT.00.475.14000/B  4.052572e+12     87141090.0
# 3781      WER.GIV.017.10001  4.052572e+12     49119900.0
# 3785      WER.GIV.023.10002  4.052572e+12            NaN
#
#                           name1_GER  \
# 100               TRAX Schloss-Satz
# 101               TRAX Schloss-Satz
# 256       BLAZE H Satteltaschen-Set
# 259   URBAN ABS Seitenkoffer-System
# 260   URBAN ABS Seitenkoffer-System
# ...                             ...
# ...

# %%
fq8_test = fq7_test[~fq7_test['ItemNr'].astype(str).str.startswith('SET')]
fq8_test
# Out:
#                      ItemNr        EAN_No  tariff_number  \
# 100        ALK.00.165.16303  4.052572e+12     83014090.0
# 101        ALK.00.165.16503  4.052572e+12     83014090.0
# 256   BC.HTA.04.740.10500/B  4.052572e+12            NaN
# 259   BC.HTA.04.915.30000/B  4.052572e+12            NaN
# 260   BC.HTA.04.958.30000/B  4.052572e+12     42021250.0
# ...                     ...           ...            ...
# 3583           TORSTEN.TEST  4.052572e+12     27101225.0
# 3584      TORSTEN.TEST_NILS  4.052572e+12     27101225.0
# 3600     TRT.00.475.14000/B  4.052572e+12     87141090.0
# 3781      WER.GIV.017.10001  4.052572e+12     49119900.0
# 3785      WER.GIV.023.10002  4.052572e+12            NaN
#
#                           name1_GER  \
# 100               TRAX Schloss-Satz
# 101               TRAX Schloss-Satz
# 256       BLAZE H Satteltaschen-Set
# 259   URBAN ABS Seitenkoffer-System
# 260   URBAN ABS Seitenkoffer-System
# ...                             ...
# ...

# %%
filtandaunc = fq8_test[fq8_test['MadeIn'] != 'AU/NOT CE']

# %%
filtandaunc
# Out:
#                      ItemNr        EAN_No  tariff_number  \
# 100        ALK.00.165.16303  4.052572e+12     83014090.0
# 101        ALK.00.165.16503  4.052572e+12     83014090.0
# 256   BC.HTA.04.740.10500/B  4.052572e+12            NaN
# 259   BC.HTA.04.915.30000/B  4.052572e+12            NaN
# 260   BC.HTA.04.958.30000/B  4.052572e+12     42021250.0
# ...                     ...           ...            ...
# 3583           TORSTEN.TEST  4.052572e+12     27101225.0
# 3584      TORSTEN.TEST_NILS  4.052572e+12     27101225.0
# 3600     TRT.00.475.14000/B  4.052572e+12     87141090.0
# 3781      WER.GIV.017.10001  4.052572e+12     49119900.0
# 3785      WER.GIV.023.10002  4.052572e+12            NaN
#
#                           name1_GER  \
# 100               TRAX Schloss-Satz
# 101               TRAX Schloss-Satz
# 256       BLAZE H Satteltaschen-Set
# 259   URBAN ABS Seitenkoffer-System
# 260   URBAN ABS Seitenkoffer-System
# ...                             ...
# ...

# %% [markdown]
# name1_ENG = "AERO ABS side case system

# %% [markdown]
# filtandaunc.to_csv('filtandaunc.csv')

# %%
faa2 = filtandaunc[filtandaunc['name1_ENG'] != 'AERO ABS side case system']

# %% [markdown]
# # FOR THIS ONE CHECK IF "with" OR "with " (space at end)

# %%
faa_with = faa2[~faa2['name1_ENG'].astype(str).str.contains('with')]
faa_with

#~ means doesnt contain with
#work on exceptions
# Out:
#                      ItemNr        EAN_No  tariff_number  \
# 100        ALK.00.165.16303  4.052572e+12     83014090.0
# 101        ALK.00.165.16503  4.052572e+12     83014090.0
# 256   BC.HTA.04.740.10500/B  4.052572e+12            NaN
# 259   BC.HTA.04.915.30000/B  4.052572e+12            NaN
# 260   BC.HTA.04.958.30000/B  4.052572e+12     42021250.0
# ...                     ...           ...            ...
# 3583           TORSTEN.TEST  4.052572e+12     27101225.0
# 3584      TORSTEN.TEST_NILS  4.052572e+12     27101225.0
# 3600     TRT.00.475.14000/B  4.052572e+12     87141090.0
# 3781      WER.GIV.017.10001  4.052572e+12     49119900.0
# 3785      WER.GIV.023.10002  4.052572e+12            NaN
#
#                           name1_GER  \
# 100               TRAX Schloss-Satz
# 101               TRAX Schloss-Satz
# 256       BLAZE H Satteltaschen-Set
# 259   URBAN ABS Seitenkoffer-System
# 260   URBAN ABS Seitenkoffer-System
# ...                             ...
# ...

# %%
#display wall/room with mounting messed up

# %% [markdown]
# name 1 eng contains set

# %%
faa_with_set = faa_with[~faa_with['name1_ENG'].astype(str).str.contains('set')]
faa_with_set
# Out:
#                      ItemNr        EAN_No  tariff_number  \
# 259   BC.HTA.04.915.30000/B  4.052572e+12            NaN
# 260   BC.HTA.04.958.30000/B  4.052572e+12     42021250.0
# 314   BC.HTA.07.649.30001/B  4.052572e+12            NaN
# 472     BC.POW.00.011.10000  4.052572e+12     85363010.0
# 525   BC.SYS.04.958.30000/B  4.052572e+12     42029298.0
# ...                     ...           ...            ...
# 3511       STS.07.945.10000  4.052572e+12     87141090.0
# 3583           TORSTEN.TEST  4.052572e+12     27101225.0
# 3584      TORSTEN.TEST_NILS  4.052572e+12     27101225.0
# 3600     TRT.00.475.14000/B  4.052572e+12     87141090.0
# 3785      WER.GIV.023.10002  4.052572e+12            NaN
#
#                               name1_GER  \
# 259       URBAN ABS Seitenkoffer-System
# 260       URBAN ABS Seitenkoffer-System
# 314       URBAN ABS Seitenkoffer-System
# 472   Adapter Elektrik-Tankring auf SAE
# 525         SysBag 15/10 Taschen-System
# ...

# %%
#with system in name 1 eng
faa_with_set_sys = faa_with_set[~faa_with_set['name1_ENG'].astype(str).str.contains('system')]
faa_with_set_sys
# Out:
#                    ItemNr        EAN_No  tariff_number  \
# 472   BC.POW.00.011.10000  4.052572e+12     85363010.0
# 610   BC.TRS.00.101.30000  4.052572e+12     42029298.0
# 613   BC.TRS.00.102.30000  4.052572e+12     42029298.0
# 616   BC.TRS.00.103.30000  4.052572e+12     42029298.0
# 621   BC.TRS.00.107.30000  4.052572e+12     42029298.0
# ...                   ...           ...            ...
# 3511     STS.07.945.10000  4.052572e+12     87141090.0
# 3583         TORSTEN.TEST  4.052572e+12     27101225.0
# 3584    TORSTEN.TEST_NILS  4.052572e+12     27101225.0
# 3600   TRT.00.475.14000/B  4.052572e+12     87141090.0
# 3785    WER.GIV.023.10002  4.052572e+12            NaN
#
#                               name1_GER  \
# 472   Adapter Elektrik-Tankring auf SAE
# 610              PRO Sport Tankrucksack
# 613              PRO Trial Tankrucksack
# 616                 PRO GS Tankrucksack
# 621             PRO Engage Tankrucksack
# ...                                 ...
# ...

# %%
#madein != us
faa_with_set_sys

nous = faa_with_set_sys[faa_with_set_sys['MadeIn'] != 'USA/NOT CE']

nous
# Out:
#                    ItemNr        EAN_No  tariff_number  \
# 610   BC.TRS.00.101.30000  4.052572e+12     42029298.0
# 613   BC.TRS.00.102.30000  4.052572e+12     42029298.0
# 616   BC.TRS.00.103.30000  4.052572e+12     42029298.0
# 621   BC.TRS.00.107.30000  4.052572e+12     42029298.0
# 630   BC.TRS.00.111.30000  4.052572e+12     42029298.0
# ...                   ...           ...            ...
# 3511     STS.07.945.10000  4.052572e+12     87141090.0
# 3583         TORSTEN.TEST  4.052572e+12     27101225.0
# 3584    TORSTEN.TEST_NILS  4.052572e+12     27101225.0
# 3600   TRT.00.475.14000/B  4.052572e+12     87141090.0
# 3785    WER.GIV.023.10002  4.052572e+12            NaN
#
#                             name1_GER  \
# 610            PRO Sport Tankrucksack
# 613            PRO Trial Tankrucksack
# 616               PRO GS Tankrucksack
# 621           PRO Engage Tankrucksack
# 630   PRO Daypack Magnet-Tankrucksack
# ...                               ...
# ...

# %%
nousnanuk = nous[~nous['name1_ENG'].astype(str).str.contains('NANUK')]
nousnanuk
# Out:
#                    ItemNr        EAN_No  tariff_number  \
# 610   BC.TRS.00.101.30000  4.052572e+12     42029298.0
# 613   BC.TRS.00.102.30000  4.052572e+12     42029298.0
# 616   BC.TRS.00.103.30000  4.052572e+12     42029298.0
# 621   BC.TRS.00.107.30000  4.052572e+12     42029298.0
# 630   BC.TRS.00.111.30000  4.052572e+12     42029298.0
# ...                   ...           ...            ...
# 3511     STS.07.945.10000  4.052572e+12     87141090.0
# 3583         TORSTEN.TEST  4.052572e+12     27101225.0
# 3584    TORSTEN.TEST_NILS  4.052572e+12     27101225.0
# 3600   TRT.00.475.14000/B  4.052572e+12     87141090.0
# 3785    WER.GIV.023.10002  4.052572e+12            NaN
#
#                             name1_GER  \
# 610            PRO Sport Tankrucksack
# 613            PRO Trial Tankrucksack
# 616               PRO GS Tankrucksack
# 621           PRO Engage Tankrucksack
# 630   PRO Daypack Magnet-Tankrucksack
# ...                               ...
# ...

# %% [markdown]
# so far check for us and with

# %% [markdown]
# # upload kit file SWM and cross reference

# %% [markdown]
# KIT DEFINITIONS : SW-MOTECH's most recent Kit Def file
#
# https://docs.google.com/spreadsheets/d/1xsmxakgHJCeSKfuUN5JACqdZ561FUvYy4nuglPRW-UY/edit#gid=0

# %%
kit = pd.read_csv('kit_6_4_google.csv', encoding = "ISO-8859-1")

kit
# Out:
#                  Unnamed: 0 SW-MOTECH's retail-facing KIT SKU in Germany  \
# 0                 Kategorie                                    Part_list
# 1     Adventure-Set GepÃ¤ck                           ADV.01.129.75000/B
# 2     Adventure-Set GepÃ¤ck                           ADV.01.129.75000/B
# 3     Adventure-Set GepÃ¤ck                           ADV.01.129.75000/B
# 4     Adventure-Set GepÃ¤ck                           ADV.01.129.75000/B
# ...                     ...                                          ...
# 5491           Crashpad Set                           STP.11.590.10100/B
# 5492           Crashpad Set                           STP.11.590.10100/B
# 5493           Crashpad Set                           STP.11.590.10300/B
# 5494           Crashpad Set                           STP.11.590.10300/B
# 5495           Crashpad Set                           STP.11.590.10400/B
#
#         Unnamed: 2                                         Unnamed: 3  \
# ...

# %% [markdown]
# rename SW-MOTECH's Kit Components, x1/ea. (Vendor Code) to kit_components

# %%
val_2 = kit['kit_components'].unique()

query_kit = nousnanuk.query("ItemNr not in @val_2")

query_kit
# Out:
#                    ItemNr        EAN_No  tariff_number  \
# 610   BC.TRS.00.101.30000  4.052572e+12     42029298.0
# 613   BC.TRS.00.102.30000  4.052572e+12     42029298.0
# 616   BC.TRS.00.103.30000  4.052572e+12     42029298.0
# 621   BC.TRS.00.107.30000  4.052572e+12     42029298.0
# 630   BC.TRS.00.111.30000  4.052572e+12     42029298.0
# ...                   ...           ...            ...
# 3511     STS.07.945.10000  4.052572e+12     87141090.0
# 3583         TORSTEN.TEST  4.052572e+12     27101225.0
# 3584    TORSTEN.TEST_NILS  4.052572e+12     27101225.0
# 3600   TRT.00.475.14000/B  4.052572e+12     87141090.0
# 3785    WER.GIV.023.10002  4.052572e+12            NaN
#
#                             name1_GER  \
# 610            PRO Sport Tankrucksack
# 613            PRO Trial Tankrucksack
# 616               PRO GS Tankrucksack
# 621           PRO Engage Tankrucksack
# 630   PRO Daypack Magnet-Tankrucksack
# ...                               ...
# ...

# %%
#reccomended retail price and TWTPrice

# %%
price1 = query_kit[query_kit['Recommended_Retail_Price'].notna()]

# %%
price2 = price1[price1['TWTPrice'].notna()]
price2
# Out:
#                    ItemNr        EAN_No  tariff_number  \
# 610   BC.TRS.00.101.30000  4.052572e+12     42029298.0
# 613   BC.TRS.00.102.30000  4.052572e+12     42029298.0
# 616   BC.TRS.00.103.30000  4.052572e+12     42029298.0
# 621   BC.TRS.00.107.30000  4.052572e+12     42029298.0
# 630   BC.TRS.00.111.30000  4.052572e+12     42029298.0
# 778   BC.ZUB.00.108.30000  4.052572e+12     42029298.0
# 779   BC.ZUB.00.109.30000  4.052572e+12     42029298.0
# 780   BC.ZUB.00.110.30000  4.052572e+12     42029298.0
# 781   BC.ZUB.00.111.30000  4.052572e+12     42029298.0
# 782   BC.ZUB.00.112.30000  4.052572e+12     42029298.0
# 783   BC.ZUB.00.113.30000  4.052572e+12     42029298.0
# 784   BC.ZUB.00.114.30000  4.052572e+12     42029298.0
# 785   BC.ZUB.00.115.30000  4.052572e+12     42029219.0
# 1086     FSC.07.945.10000  4.052572e+12            NaN
# 1088     FSC.08.261.10001  4.052572e+12     87141090.0
# 1191   GPT.00.152.36100/B  4.052572e+12     87141090.0
# ...

# %% [markdown]
# Should Be
# ALK.00.165.16503 lock SET
# BC.TRS.00.101.30000
# BC.TRS.00.102.30000
# BC.TRS.00.103.30000
# BC.TRS.00.107.30000
# BC.TRS.00.111.30000
# BC.ZUB.00.108.30000
# BC.ZUB.00.109.30000
# BC.ZUB.00.110.30000
# BC.ZUB.00.111.30000
# BC.ZUB.00.112.30000
# BC.ZUB.00.113.30000
# BC.ZUB.00.114.30000
# BC.ZUB.00.115.30000
# DGS.00.910.21400       a
# DGS.00.910.21500        a
# FRS.06.112.80200/S       a
# FSC.07.945.10000
# FSC.08.261.10001
# GPT.00.152.36100/B
# GPT.00.152.55200/B
# GPT.00.152.55300/B
# GPT.01.950.19000/B
# GPT.06.525.16000/B
# GPT.07.945.16000/B
# HPR.00.220.24600/B
# HPS.01.147.10001/B
# HPS.07.951.10000/B
# HTA.07.740.81100/B
# HTA.07.945.10000
# HTA.07.945.11000
# KFT.07.949.30000/B
# MSS.05.936.10000
# SBL.01.622.10004/B
# SBL.01.942.10100/B
# SBL.04.521.10100/EB
# SBL.05.936.10000/B
# SBL.05.936.10100/B
# SBL.07.945.10000/B
# STP.07.590.10900/B
# STP.07.590.80900/B
# STS.07.945.10000
# WER.GIV.017.10001

# %%
price2 #to csv
# Out:
#                    ItemNr        EAN_No  tariff_number  \
# 610   BC.TRS.00.101.30000  4.052572e+12     42029298.0
# 613   BC.TRS.00.102.30000  4.052572e+12     42029298.0
# 616   BC.TRS.00.103.30000  4.052572e+12     42029298.0
# 621   BC.TRS.00.107.30000  4.052572e+12     42029298.0
# 630   BC.TRS.00.111.30000  4.052572e+12     42029298.0
# 778   BC.ZUB.00.108.30000  4.052572e+12     42029298.0
# 779   BC.ZUB.00.109.30000  4.052572e+12     42029298.0
# 780   BC.ZUB.00.110.30000  4.052572e+12     42029298.0
# 781   BC.ZUB.00.111.30000  4.052572e+12     42029298.0
# 782   BC.ZUB.00.112.30000  4.052572e+12     42029298.0
# 783   BC.ZUB.00.113.30000  4.052572e+12     42029298.0
# 784   BC.ZUB.00.114.30000  4.052572e+12     42029298.0
# 785   BC.ZUB.00.115.30000  4.052572e+12     42029219.0
# 1086     FSC.07.945.10000  4.052572e+12            NaN
# 1088     FSC.08.261.10001  4.052572e+12     87141090.0
# 1191   GPT.00.152.36100/B  4.052572e+12     87141090.0
# ...

# %% [markdown]
# # think this is all the ones needed to be uploaded as of davids document (28) probably missed 2 that said "with"

# %% [markdown]
# # ,manually gotta do exceptions thats the only thing left

# %%
faa_with

#work on exceptions
# Out:
#                      ItemNr        EAN_No  tariff_number  \
# 100        ALK.00.165.16303  4.052572e+12     83014090.0
# 101        ALK.00.165.16503  4.052572e+12     83014090.0
# 256   BC.HTA.04.740.10500/B  4.052572e+12            NaN
# 259   BC.HTA.04.915.30000/B  4.052572e+12            NaN
# 260   BC.HTA.04.958.30000/B  4.052572e+12     42021250.0
# ...                     ...           ...            ...
# 3583           TORSTEN.TEST  4.052572e+12     27101225.0
# 3584      TORSTEN.TEST_NILS  4.052572e+12     27101225.0
# 3600     TRT.00.475.14000/B  4.052572e+12     87141090.0
# 3781      WER.GIV.017.10001  4.052572e+12     49119900.0
# 3785      WER.GIV.023.10002  4.052572e+12            NaN
#
#                           name1_GER  \
# 100               TRAX Schloss-Satz
# 101               TRAX Schloss-Satz
# 256       BLAZE H Satteltaschen-Set
# 259   URBAN ABS Seitenkoffer-System
# 260   URBAN ABS Seitenkoffer-System
# ...                             ...
# ...

# %%
price2.to_csv('6_3_done_part_1.csv')
#minus like 2
#tthis is the ones that should say "upload"

# %%
nous
# Out:
#                    ItemNr        EAN_No  tariff_number  \
# 610   BC.TRS.00.101.30000  4.052572e+12     42029298.0
# 613   BC.TRS.00.102.30000  4.052572e+12     42029298.0
# 616   BC.TRS.00.103.30000  4.052572e+12     42029298.0
# 621   BC.TRS.00.107.30000  4.052572e+12     42029298.0
# 630   BC.TRS.00.111.30000  4.052572e+12     42029298.0
# ...                   ...           ...            ...
# 3511     STS.07.945.10000  4.052572e+12     87141090.0
# 3583         TORSTEN.TEST  4.052572e+12     27101225.0
# 3584    TORSTEN.TEST_NILS  4.052572e+12     27101225.0
# 3600   TRT.00.475.14000/B  4.052572e+12     87141090.0
# 3785    WER.GIV.023.10002  4.052572e+12            NaN
#
#                             name1_GER  \
# 610            PRO Sport Tankrucksack
# 613            PRO Trial Tankrucksack
# 616               PRO GS Tankrucksack
# 621           PRO Engage Tankrucksack
# 630   PRO Daypack Magnet-Tankrucksack
# ...                               ...
# ...

# %%
price10 = query_kit[query_kit['Recommended_Retail_Price'].notna()]

price20 = nous[nous['TWTPrice'].notna()]
price20
# Out:
#                    ItemNr        EAN_No  tariff_number  \
# 610   BC.TRS.00.101.30000  4.052572e+12     42029298.0
# 613   BC.TRS.00.102.30000  4.052572e+12     42029298.0
# 616   BC.TRS.00.103.30000  4.052572e+12     42029298.0
# 621   BC.TRS.00.107.30000  4.052572e+12     42029298.0
# 630   BC.TRS.00.111.30000  4.052572e+12     42029298.0
# 778   BC.ZUB.00.108.30000  4.052572e+12     42029298.0
# 779   BC.ZUB.00.109.30000  4.052572e+12     42029298.0
# 780   BC.ZUB.00.110.30000  4.052572e+12     42029298.0
# 781   BC.ZUB.00.111.30000  4.052572e+12     42029298.0
# 782   BC.ZUB.00.112.30000  4.052572e+12     42029298.0
# 783   BC.ZUB.00.113.30000  4.052572e+12     42029298.0
# 784   BC.ZUB.00.114.30000  4.052572e+12     42029298.0
# 785   BC.ZUB.00.115.30000  4.052572e+12     42029219.0
# 989    FRS.06.112.80200/S  4.052572e+12            NaN
# 1086     FSC.07.945.10000  4.052572e+12            NaN
# 1088     FSC.08.261.10001  4.052572e+12     87141090.0
# ...

# %%
price20.to_csv('6_8_done_part_1.csv')

# %%
#with set kit 5 missing

# %% [markdown]
# # 6_8_done_part_1 is good but theres 5 missing from it:
# ALK.00.165.16503
#
# DGS.00.910.21400
#
# DGS.00.910.21500
#
# HPR.00.220.24600/B
#
# WER.GIV.017.10001

# %%
price20.columns
# Out:
# Index(['ItemNr', 'EAN_No', 'tariff_number', 'name1_GER', 'name2_GER',
#        'name1_ENG', 'name2_ENG', 'name1_ESP', 'name2_ESP', 'name1_FRA',
#        'name2_FRA', 'TechApproval', 'in_shop_from', 'shop_Category_ENG',
#        'shop_Kategorie_GER', 'availability', 'expected', 'PartList',
#        'ItemGroup', 'AproxDeliverable', 'Replaces', 'Discontinued',
#        'Reason_of_revision', 'ExpecAvailabilityMonth', 'ReplacedBy', 'Weight',
#        'MadeIn', 'Recommended_Retail_Price', 'TWTPrice', 'Currency',
#        'MainPicture', 'Picture2', 'Picture3', 'Picture4', 'Picture5',
#        'MountingInstructions', 'Videolink', 'DescriptionGER', 'DescriptionENG',
#        'DescriptionESP', 'DescriptionFRA'],
#       dtype='object')

# %%
faa2[faa2['ItemNr'] == 'ALK.00.165.16503']
#faa2[faa2.ItemNr == 'DGS.00.910.21400']
     #DGS.00.910.21500', 'HPR.00.220.24600/B', 'WER.GIV.017.10001']
# Out:
#                ItemNr        EAN_No  tariff_number          name1_GER  \
# 101  ALK.00.165.16503  4.052572e+12     83014090.0  TRAX Schloss-Satz
#
#                                       name2_GER      name1_ENG  \
# 101  2 Schlösser/2 Schlüssel. Gleichschließend.  TRAX lock set
#
#                                    name2_ENG  \
# 101  2 locks / 2 keys. Simultaneous locking.
#
#                                 name1_ESP  \
# 101  TRAX juego de cerraduras cilíndricas
#
#                                      name2_ESP             name1_FRA  ...  \
# 101  2 cerraduras / 2 llaves. Cierre uniforme.  TRAX kit de serrures  ...
#
#                                               Picture2  \
# 101  =HYPERLINK("https://sw-motech.com/cosmoshop/do...
#
#                                               Picture3  \
# 101  =HYPERLINK("https://sw-motech.com/cosmoshop/do...
#
#                                               Picture4  \
# 101  =HYPERLINK("https://sw-motech.com/cosmoshop/do...
#
# ...

# %%
#contains 2020

# %%
exceptions = faa2[faa2['in_shop_from'].astype(str).str.contains('2020')]

#nousnanuk = nous[~nous['name1_ENG'].astype(str).str.contains('NANUK')]

exceptions
# Out:
#                      ItemNr        EAN_No  tariff_number  \
# 101        ALK.00.165.16503  4.052572e+12     83014090.0
# 574   BC.SYS.08.866.30000/B  4.052572e+12            NaN
# 610     BC.TRS.00.101.30000  4.052572e+12     42029298.0
# 613     BC.TRS.00.102.30000  4.052572e+12     42029298.0
# 616     BC.TRS.00.103.30000  4.052572e+12     42029298.0
# 621     BC.TRS.00.107.30000  4.052572e+12     42029298.0
# 630     BC.TRS.00.111.30000  4.052572e+12     42029298.0
# 778     BC.ZUB.00.108.30000  4.052572e+12     42029298.0
# 779     BC.ZUB.00.109.30000  4.052572e+12     42029298.0
# 780     BC.ZUB.00.110.30000  4.052572e+12     42029298.0
# 781     BC.ZUB.00.111.30000  4.052572e+12     42029298.0
# 782     BC.ZUB.00.112.30000  4.052572e+12     42029298.0
# 783     BC.ZUB.00.113.30000  4.052572e+12     42029298.0
# 784     BC.ZUB.00.114.30000  4.052572e+12     42029298.0
# 785     BC.ZUB.00.115.30000  4.052572e+12     42029219.0
# ...

# %%
#exceptions[]
exceptions_add = []

#exceptions[exceptions['ItemNr'] == 'ALK.00.165.16503']

# %%
e1 = exceptions[exceptions['name1_ENG'] == 'TRAX lock set']

# %%
e2 = exceptions[exceptions['name1_ENG'] == 'Sales display wall with mounting']

# %%
e3 = exceptions[exceptions['name1_ENG'] == 'Sales display room with mounting']

# %%
kobra_exc = fq2[fq2['name1_ENG'] == 'KOBRA handguard kit']
#kobra_exc.to_csv('kobra_exc_test.csv')
e4 = kobra_exc[kobra_exc['MadeIn'] == 'AU/NOT CE']

# %%
#Sticker set SW-MOTECH
e5 = exceptions[exceptions['name1_ENG'] == 'Sticker set SW-MOTECH']

# %%
#now append e1,e2,e3,e4,e5 to price 20 and export as csv

# %%
final_a1 = price20.append(e1)
final_a1
# Out:
#                    ItemNr        EAN_No  tariff_number  \
# 610   BC.TRS.00.101.30000  4.052572e+12     42029298.0
# 613   BC.TRS.00.102.30000  4.052572e+12     42029298.0
# 616   BC.TRS.00.103.30000  4.052572e+12     42029298.0
# 621   BC.TRS.00.107.30000  4.052572e+12     42029298.0
# 630   BC.TRS.00.111.30000  4.052572e+12     42029298.0
# 778   BC.ZUB.00.108.30000  4.052572e+12     42029298.0
# 779   BC.ZUB.00.109.30000  4.052572e+12     42029298.0
# 780   BC.ZUB.00.110.30000  4.052572e+12     42029298.0
# 781   BC.ZUB.00.111.30000  4.052572e+12     42029298.0
# 782   BC.ZUB.00.112.30000  4.052572e+12     42029298.0
# 783   BC.ZUB.00.113.30000  4.052572e+12     42029298.0
# 784   BC.ZUB.00.114.30000  4.052572e+12     42029298.0
# 785   BC.ZUB.00.115.30000  4.052572e+12     42029219.0
# 989    FRS.06.112.80200/S  4.052572e+12            NaN
# 1086     FSC.07.945.10000  4.052572e+12            NaN
# 1088     FSC.08.261.10001  4.052572e+12     87141090.0
# ...

# %%
final_a2 = final_a1.append(e2)
final_a2
# Out:
#                    ItemNr        EAN_No  tariff_number  \
# 610   BC.TRS.00.101.30000  4.052572e+12     42029298.0
# 613   BC.TRS.00.102.30000  4.052572e+12     42029298.0
# 616   BC.TRS.00.103.30000  4.052572e+12     42029298.0
# 621   BC.TRS.00.107.30000  4.052572e+12     42029298.0
# 630   BC.TRS.00.111.30000  4.052572e+12     42029298.0
# 778   BC.ZUB.00.108.30000  4.052572e+12     42029298.0
# 779   BC.ZUB.00.109.30000  4.052572e+12     42029298.0
# 780   BC.ZUB.00.110.30000  4.052572e+12     42029298.0
# 781   BC.ZUB.00.111.30000  4.052572e+12     42029298.0
# 782   BC.ZUB.00.112.30000  4.052572e+12     42029298.0
# 783   BC.ZUB.00.113.30000  4.052572e+12     42029298.0
# 784   BC.ZUB.00.114.30000  4.052572e+12     42029298.0
# 785   BC.ZUB.00.115.30000  4.052572e+12     42029219.0
# 989    FRS.06.112.80200/S  4.052572e+12            NaN
# 1086     FSC.07.945.10000  4.052572e+12            NaN
# 1088     FSC.08.261.10001  4.052572e+12     87141090.0
# ...

# %%
final_a3 = final_a2.append(e3)
final_a3
# Out:
#                    ItemNr        EAN_No  tariff_number  \
# 610   BC.TRS.00.101.30000  4.052572e+12     42029298.0
# 613   BC.TRS.00.102.30000  4.052572e+12     42029298.0
# 616   BC.TRS.00.103.30000  4.052572e+12     42029298.0
# 621   BC.TRS.00.107.30000  4.052572e+12     42029298.0
# 630   BC.TRS.00.111.30000  4.052572e+12     42029298.0
# 778   BC.ZUB.00.108.30000  4.052572e+12     42029298.0
# 779   BC.ZUB.00.109.30000  4.052572e+12     42029298.0
# 780   BC.ZUB.00.110.30000  4.052572e+12     42029298.0
# 781   BC.ZUB.00.111.30000  4.052572e+12     42029298.0
# 782   BC.ZUB.00.112.30000  4.052572e+12     42029298.0
# 783   BC.ZUB.00.113.30000  4.052572e+12     42029298.0
# 784   BC.ZUB.00.114.30000  4.052572e+12     42029298.0
# 785   BC.ZUB.00.115.30000  4.052572e+12     42029219.0
# 989    FRS.06.112.80200/S  4.052572e+12            NaN
# 1086     FSC.07.945.10000  4.052572e+12            NaN
# 1088     FSC.08.261.10001  4.052572e+12     87141090.0
# ...

# %%
final_a4 = final_a3.append(e4)
final_a4
# Out:
#                    ItemNr        EAN_No  tariff_number  \
# 610   BC.TRS.00.101.30000  4.052572e+12     42029298.0
# 613   BC.TRS.00.102.30000  4.052572e+12     42029298.0
# 616   BC.TRS.00.103.30000  4.052572e+12     42029298.0
# 621   BC.TRS.00.107.30000  4.052572e+12     42029298.0
# 630   BC.TRS.00.111.30000  4.052572e+12     42029298.0
# 778   BC.ZUB.00.108.30000  4.052572e+12     42029298.0
# 779   BC.ZUB.00.109.30000  4.052572e+12     42029298.0
# 780   BC.ZUB.00.110.30000  4.052572e+12     42029298.0
# 781   BC.ZUB.00.111.30000  4.052572e+12     42029298.0
# 782   BC.ZUB.00.112.30000  4.052572e+12     42029298.0
# 783   BC.ZUB.00.113.30000  4.052572e+12     42029298.0
# 784   BC.ZUB.00.114.30000  4.052572e+12     42029298.0
# 785   BC.ZUB.00.115.30000  4.052572e+12     42029219.0
# 989    FRS.06.112.80200/S  4.052572e+12            NaN
# 1086     FSC.07.945.10000  4.052572e+12            NaN
# 1088     FSC.08.261.10001  4.052572e+12     87141090.0
# ...

# %%
final_a5 = final_a4.append(e5)
final_a5
# Out:
#                    ItemNr        EAN_No  tariff_number  \
# 610   BC.TRS.00.101.30000  4.052572e+12     42029298.0
# 613   BC.TRS.00.102.30000  4.052572e+12     42029298.0
# 616   BC.TRS.00.103.30000  4.052572e+12     42029298.0
# 621   BC.TRS.00.107.30000  4.052572e+12     42029298.0
# 630   BC.TRS.00.111.30000  4.052572e+12     42029298.0
# 778   BC.ZUB.00.108.30000  4.052572e+12     42029298.0
# 779   BC.ZUB.00.109.30000  4.052572e+12     42029298.0
# 780   BC.ZUB.00.110.30000  4.052572e+12     42029298.0
# 781   BC.ZUB.00.111.30000  4.052572e+12     42029298.0
# 782   BC.ZUB.00.112.30000  4.052572e+12     42029298.0
# 783   BC.ZUB.00.113.30000  4.052572e+12     42029298.0
# 784   BC.ZUB.00.114.30000  4.052572e+12     42029298.0
# 785   BC.ZUB.00.115.30000  4.052572e+12     42029219.0
# 989    FRS.06.112.80200/S  4.052572e+12            NaN
# 1086     FSC.07.945.10000  4.052572e+12            NaN
# 1088     FSC.08.261.10001  4.052572e+12     87141090.0
# ...

# %%
final_a5.to_csv('final_complete_6_8.csv')

# %%
from cx_Freeze import setup, Executable

base = None    

executables = [Executable("process_part_1.py", base=base)]

packages = ["idna"]
options = {
    'build_exe': {    
        'packages':packages,
    },    
}

setup(
    name = "<any name>",
    options = options,
    version = "<any number>",
    description = '<any description>',
    executables = executables
)
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: usage: ipykernel_launcher.py [global_opts] cmd1 [cmd1_opts] [cmd2 [cmd2_opts] ...]
#    or: ipykernel_launcher.py --help [cmd1 cmd2 ...]
#    or: ipykernel_launcher.py --help-commands
#    or: ipykernel_launcher.py cmd --help
#
# error: option -f not recognized
